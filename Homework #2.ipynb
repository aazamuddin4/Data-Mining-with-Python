# %%
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt  

# %matplotlib  inline

# %%
df = pd.read_csv('country_vaccinations_by_manufacturer.csv')

# %%
df.shape
# Out:
# (6796, 4)

# %%
df.head(15)
# Out:
#    location        date             vaccine  total_vaccinations
# 0   Austria  2021-01-05     Johnson&Johnson                   0
# 1   Austria  2021-01-05             Moderna                   0
# 2   Austria  2021-01-05  Oxford/AstraZeneca                   0
# 3   Austria  2021-01-05     Pfizer/BioNTech               30829
# 4   Austria  2021-01-12     Johnson&Johnson                   0
# 5   Austria  2021-01-12             Moderna                  88
# 6   Austria  2021-01-12  Oxford/AstraZeneca                   0
# 7   Austria  2021-01-12     Pfizer/BioNTech              114966
# 8   Austria  2021-01-19     Johnson&Johnson                   0
# 9   Austria  2021-01-19             Moderna                 298
# 10  Austria  2021-01-19  Oxford/AstraZeneca                   0
# 11  Austria  2021-01-19     Pfizer/BioNTech              211955
# 12  Austria  2021-01-26     Johnson&Johnson                   0
# 13  Austria  2021-01-26             Moderna                4144
# ...

# %%
#The day of the week with Monday=0, Sunday=6
s = pd.date_range('2021-01-05', '2021-06-08', freq='D').to_series()
s.dt.dayofweek
# Out:
# 2021-01-05    1
# 2021-01-06    2
# 2021-01-07    3
# 2021-01-08    4
# 2021-01-09    5
#              ..
# 2021-06-04    4
# 2021-06-05    5
# 2021-06-06    6
# 2021-06-07    0
# 2021-06-08    1
# Freq: D, Length: 155, dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of      location        date             vaccine  total_vaccinations
# 0     Austria  2021-01-05     Johnson&Johnson                   0
# 1     Austria  2021-01-05             Moderna                   0
# 2     Austria  2021-01-05  Oxford/AstraZeneca                   0
# 3     Austria  2021-01-05     Pfizer/BioNTech               30829
# 4     Austria  2021-01-12     Johnson&Johnson                   0
# ...       ...         ...                 ...                 ...
# 6791  Uruguay  2021-06-07     Pfizer/BioNTech              711722
# 6792  Uruguay  2021-06-07             Sinovac             2304124
# 6793  Uruguay  2021-06-08  Oxford/AstraZeneca               43028
# 6794  Uruguay  2021-06-08     Pfizer/BioNTech              714663
# 6795  Uruguay  2021-06-08             Sinovac             2337157
#
# [6796 rows x 4 columns]>

# %%
df[['location', 'vaccine', 'total_vaccinations']]
# Out:
#      location             vaccine  total_vaccinations
# 0     Austria     Johnson&Johnson                   0
# 1     Austria             Moderna                   0
# 2     Austria  Oxford/AstraZeneca                   0
# 3     Austria     Pfizer/BioNTech               30829
# 4     Austria     Johnson&Johnson                   0
# ...       ...                 ...                 ...
# 6791  Uruguay     Pfizer/BioNTech              711722
# 6792  Uruguay             Sinovac             2304124
# 6793  Uruguay  Oxford/AstraZeneca               43028
# 6794  Uruguay     Pfizer/BioNTech              714663
# 6795  Uruguay             Sinovac             2337157
#
# [6796 rows x 3 columns]

# %%
sns.boxplot(df.total_vaccinations)
# Out:
# C:\Users\Andi Azam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_vaccinations'>

# %%
df=df[df.total_vaccinations<=1000000]

# %%
# Make a box plot from DataFrame columns without outliers
sns.boxplot(df.total_vaccinations)
# Out:
# C:\Users\Andi Azam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_vaccinations'>

# %%
# creates histogram plots
df.total_vaccinations.hist()
# Out:
# <AxesSubplot:>

# %%
# distribution of single variables and relationships between two variables
sns.pairplot(df[['location', 'vaccine', 'total_vaccinations']], hue='location')
sns.pairplot(df)

# %%
# Group the strips by a categorical variable
sns.stripplot(x=df.location, y=df.total_vaccinations)
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_vaccinations'>

# %%
# Draw a vertical violinplot grouped by a categorical variable
sns.violinplot(x=df.location, y=df.total_vaccinations)
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_vaccinations'>
